# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
cs_totals = pd.read_excel('./cs_totals.xlsx', index_col =0)

# %%
cs_totals['시도교육청'].unique()
# Out:
# array(['부산', '충북', '충남', '대구', '광주', '경북', '경기', '경남', '인천', '제주', '전북',
#        '전남', '강원', '세종', '서울', '울산'], dtype=object)

# %% [markdown]
# # 전국 폐교 데이터

# %%
cs_all = cs_totals.drop(['급별'], axis = 'columns')

# %%
cs_all = cs_all.groupby(('폐교년도'),  as_index =False).count()

# %%
cs_all= cs_all.rename(columns = {'시도교육청':'폐교 수'})

# %%
cs_all['폐교년도'] = cs_all['폐교년도'].astype('str')

# %%
#상관분석을 위한 파일 저장
cs_all.to_excel('./cs_all.xlsx')

# %%
#시계열그래프 시각화

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_all['폐교년도'], cs_all['폐교 수'], color = 'orange', label='Closed School')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper left', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_all')

# %% [markdown]
# # 각 지역별 폐교 데이터

# %%
#시점데이터 사전형식으로 정리
time = ['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', 
                '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
time_dic = {'폐교년도' : time}

# %%
#DataFrame형식 변환
time_df = pd.DataFrame(time_dic)

# %%
#부산
busan = (cs_totals["시도교육청"] == '부산')
busan_if = cs_totals[busan]
cs_bu = busan_if.groupby(('폐교년도'),  as_index =False).count()
cs_bu = cs_bu.drop(['급별'], axis = 'columns')
cs_bu = cs_bu.rename(columns = {'시도교육청':'폐교 수'})
cs_bu['폐교년도'] = cs_bu['폐교년도'].astype('str')

# %%
#left join
cs_busan = pd.merge(time_df, cs_bu, how='left')

# %%
#결측치들을 '0'으로 변환
cs_busan = cs_busan.fillna(0)

# %%
#시계열그래프 시각화_부산

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_busan['폐교년도'], cs_busan['폐교 수'], color = 'orange', label='Busan')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Busan Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper left', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_busan.jpg')

# %%
#충북
chungbuk = (cs_totals["시도교육청"] == '충북')
chungbuk_if = cs_totals[chungbuk]
cs_chub = chungbuk_if.groupby(('폐교년도'),  as_index =False).count()
cs_chub = cs_chub.drop(['급별'], axis = 'columns')
cs_chub = cs_chub.rename(columns = {'시도교육청':'폐교 수'})
cs_chub['폐교년도'] = cs_chub['폐교년도'].astype('str')

# %%
#left join
cs_chungbuk = pd.merge(time_df, cs_chub, how='left')

# %%
#결측치들을 '0'으로 변환
cs_chungbuk = cs_chungbuk.fillna(0)

# %%
#시계열그래프 시각화_충북

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_chungbuk['폐교년도'], cs_chungbuk['폐교 수'], color = 'orange', label='Chungbuk')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Chungbuk Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper left', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_chungbuk.jpg')

# %%
#충남
chungnam = (cs_totals["시도교육청"] == '충남')
chungnam_if = cs_totals[chungnam]
cs_chun = chungnam_if.groupby(('폐교년도'),  as_index =False).count()
cs_chun = cs_chun.drop(['급별'], axis = 'columns')
cs_chun = cs_chun.rename(columns = {'시도교육청':'폐교 수'})
cs_chun['폐교년도'] = cs_chun['폐교년도'].astype('str')

# %%
#left join
cs_chungnam = pd.merge(time_df, cs_chun, how='left')

# %%
#결측치들을 '0'으로 변환
cs_chungnam = cs_chungnam.fillna(0)

# %%
#시계열그래프 시각화_충남

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_chungnam['폐교년도'], cs_chungnam['폐교 수'], color = 'orange', label='Chungnam')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Chungnam Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper left', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_chungnam.jpg')

# %%
#대구
daegu = (cs_totals["시도교육청"] == '대구')
daegu_if = cs_totals[daegu]
cs_daeg = daegu_if.groupby(('폐교년도'),  as_index =False).count()
cs_daeg = cs_daeg.drop(['급별'], axis = 'columns')
cs_daeg = cs_daeg.rename(columns = {'시도교육청':'폐교 수'})
cs_daeg['폐교년도'] = cs_daeg['폐교년도'].astype('str')

# %%
#left join
cs_daegu = pd.merge(time_df, cs_daeg, how='left')

# %%
#결측치들을 '0'으로 변환
cs_daegu = cs_daegu.fillna(0)

# %%
#시계열그래프 시각화_대구

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_daegu['폐교년도'], cs_daegu['폐교 수'], color = 'orange', label='Daegu')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Daegu Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper left', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_daegu.jpg')

# %%
#광주
gwangju = (cs_totals["시도교육청"] == '광주')
gwangju_if = cs_totals[gwangju]
cs_gwa = gwangju_if.groupby(('폐교년도'),  as_index =False).count()
cs_gwa = cs_gwa.drop(['급별'], axis = 'columns')
cs_gwa = cs_gwa.rename(columns = {'시도교육청':'폐교 수'})
cs_gwa['폐교년도'] = cs_gwa['폐교년도'].astype('str')

# %%
#left join
cs_gwangju = pd.merge(time_df, cs_gwa, how='left')

# %%
#결측치들을 '0'으로 변환
cs_gwangju = cs_gwangju.fillna(0)

# %%
#시계열그래프 시각화_광주

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_gwangju['폐교년도'], cs_gwangju['폐교 수'], color = 'orange', label='Gwangju')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Gwangju Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper left', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_gwangju.jpg')

# %%
#경북
gyeongbuk = (cs_totals["시도교육청"] == '경북')
gyeongbuk_if = cs_totals[gyeongbuk]
cs_gyeb = gyeongbuk_if.groupby(('폐교년도'),  as_index =False).count()
cs_gyeb = cs_gyeb.drop(['급별'], axis = 'columns')
cs_gyeb = cs_gyeb.rename(columns = {'시도교육청':'폐교 수'})
cs_gyeb['폐교년도'] = cs_gyeb['폐교년도'].astype('str')

# %%
#left join
cs_gyeongbuk = pd.merge(time_df, cs_gyeb, how='left')

# %%
#결측치들을 '0'으로 변환
cs_gyeongbuk = cs_gyeongbuk.fillna(0)

# %%
#시계열그래프 시각화_경북

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_gyeongbuk['폐교년도'], cs_gyeongbuk['폐교 수'], color = 'orange', label='Gyeongbuk')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Gyeongbuk Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper left', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_gyeongbuk.jpg')

# %%
#경기
gyeonggi = (cs_totals["시도교육청"] == '경기')
gyeonggi_if = cs_totals[gyeonggi]
cs_gye = gyeonggi_if.groupby(('폐교년도'),  as_index =False).count()
cs_gye = cs_gye.drop(['급별'], axis = 'columns')
cs_gye = cs_gye.rename(columns = {'시도교육청':'폐교 수'})
cs_gye['폐교년도'] = cs_gye['폐교년도'].astype('str')

# %%
#left join
cs_gyeonggi = pd.merge(time_df, cs_gye, how='left')

# %%
#결측치들을 '0'으로 변환
cs_gyeonggi = cs_gyeonggi.fillna(0)

# %%
#시계열그래프 시각화_경기

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_gyeonggi['폐교년도'], cs_gyeonggi['폐교 수'], color = 'orange', label='Gyeonggi')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Gyeonggi Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper right', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_gyeonggi.jpg')

# %%
#경남
gyeongnam = (cs_totals["시도교육청"] == '경남')
gyeongnam_if = cs_totals[gyeongnam]
cs_gyen = gyeongnam_if.groupby(('폐교년도'),  as_index =False).count()
cs_gyen = cs_gyen.drop(['급별'], axis = 'columns')
cs_gyen = cs_gyen.rename(columns = {'시도교육청':'폐교 수'})
cs_gyen['폐교년도'] = cs_gyen['폐교년도'].astype('str')

# %%
#left join
cs_gyeongnam = pd.merge(time_df, cs_gyen, how='left')

# %%
#결측치들을 '0'으로 변환
cs_gyeongnam = cs_gyeongnam.fillna(0)

# %%
#시계열그래프 시각화_경남

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_gyeongnam['폐교년도'], cs_gyeongnam['폐교 수'], color = 'orange', label='Gyeongnam')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Gyeongnam Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper right', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_gyeongnam.jpg')

# %%
#인천
incheon = (cs_totals["시도교육청"] == '인천')
incheon_if = cs_totals[incheon]
cs_inc = incheon_if.groupby(('폐교년도'),  as_index =False).count()
cs_inc = cs_inc.drop(['급별'], axis = 'columns')
cs_inc = cs_inc.rename(columns = {'시도교육청':'폐교 수'})
cs_inc['폐교년도'] = cs_inc['폐교년도'].astype('str')

# %%
#left join
cs_incheon = pd.merge(time_df, cs_inc, how='left')

# %%
#결측치들을 '0'으로 변환
cs_incheon = cs_incheon.fillna(0)

# %%
#시계열그래프 시각화_인천

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_incheon['폐교년도'], cs_incheon['폐교 수'], color = 'orange', label='Incheon')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Incheon Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper right', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_incheon.jpg')

# %%
#제주
jeju = (cs_totals["시도교육청"] == '제주')
jeju_if = cs_totals[jeju]
cs_jej = jeju_if.groupby(('폐교년도'),  as_index =False).count()
cs_jej = cs_jej.drop(['급별'], axis = 'columns')
cs_jej = cs_jej.rename(columns = {'시도교육청':'폐교 수'})
cs_jej['폐교년도'] = cs_jej['폐교년도'].astype('str')

# %%
#left join
cs_jeju = pd.merge(time_df, cs_jej, how='left')

# %%
#결측치들을 '0'으로 변환
cs_jeju = cs_jeju.fillna(0)

# %%
#시계열그래프 시각화_제주

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_jeju['폐교년도'], cs_jeju['폐교 수'], color = 'orange', label='Jeju')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Jeju Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper right', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_jeju.jpg')

# %%
#전북
jeonbuk = (cs_totals["시도교육청"] == '전북')
jeonbuk_if = cs_totals[jeonbuk]
cs_jeob = jeonbuk_if.groupby(('폐교년도'),  as_index =False).count()
cs_jeob = cs_jeob.drop(['급별'], axis = 'columns')
cs_jeob = cs_jeob.rename(columns = {'시도교육청':'폐교 수'})
cs_jeob['폐교년도'] = cs_jeob['폐교년도'].astype('str')

# %%
#left join
cs_jeonbuk = pd.merge(time_df, cs_jeob, how='left')

# %%
#결측치들을 '0'으로 변환
cs_jeonbuk = cs_jeonbuk.fillna(0)

# %%
#시계열그래프 시각화_전북

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_jeonbuk['폐교년도'], cs_jeonbuk['폐교 수'], color = 'orange', label='Jeonbuk')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Jeonbuk Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper right', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_Jeonbuk.jpg')

# %%
#전남
jeonnam = (cs_totals["시도교육청"] == '전남')
jeonnam_if = cs_totals[jeonnam]
cs_jeon = jeonnam_if.groupby(('폐교년도'),  as_index =False).count()
cs_jeon = cs_jeon.drop(['급별'], axis = 'columns')
cs_jeon = cs_jeon.rename(columns = {'시도교육청':'폐교 수'})
cs_jeon['폐교년도'] = cs_jeon['폐교년도'].astype('str')

# %%
#left join
cs_jeonnam = pd.merge(time_df, cs_jeon, how='left')

# %%
#결측치들을 '0'으로 변환
cs_jeonnam = cs_jeonnam.fillna(0)

# %%
#시계열그래프 시각화_전남

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_jeonnam['폐교년도'], cs_jeonnam['폐교 수'], color = 'orange', label='Jeonnam')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Jeonnam Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper right', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_jeonnam.jpg')

# %%
#강원
kangwon = (cs_totals["시도교육청"] == '강원')
kangwon_if = cs_totals[kangwon]
cs_kang = kangwon_if.groupby(('폐교년도'),  as_index =False).count()
cs_kang = cs_kang.drop(['급별'], axis = 'columns')
cs_kang = cs_kang.rename(columns = {'시도교육청':'폐교 수'})
cs_kang['폐교년도'] = cs_kang['폐교년도'].astype('str')

# %%
#left join
cs_kangwon = pd.merge(time_df, cs_kang, how='left')

# %%
#결측치들을 '0'으로 변환
cs_kangwon = cs_kangwon.fillna(0)

# %%
#시계열그래프 시각화_강원

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_kangwon['폐교년도'], cs_kangwon['폐교 수'], color = 'orange', label='Kangwon')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Kangwoni Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper right', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_kangwon.jpg')

# %%
#세종
sejung = (cs_totals["시도교육청"] == '세종')
sejung_if = cs_totals[sejung]
cs_sej = sejung_if.groupby(('폐교년도'),  as_index =False).count()
cs_sej = cs_sej.drop(['급별'], axis = 'columns')
cs_sej = cs_sej.rename(columns = {'시도교육청':'폐교 수'})
cs_sej['폐교년도'] = cs_sej['폐교년도'].astype('str')

# %%
#left join
cs_sejung = pd.merge(time_df, cs_sej, how='left')

# %%
#결측치들을 '0'으로 변환
cs_sejung = cs_sejung.fillna(0)

# %%
#시계열그래프 시각화_세종

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_sejung['폐교년도'], cs_sejung['폐교 수'], color = 'orange', label='Sejung')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Sejung Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper right', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_sejung.jpg')

# %%
#서울
seoul = (cs_totals["시도교육청"] == '서울')
seoul_if = cs_totals[seoul]
cs_seo = seoul_if.groupby(('폐교년도'),  as_index =False).count()
cs_seo = cs_seo.drop(['급별'], axis = 'columns')
cs_seo = cs_seo.rename(columns = {'시도교육청':'폐교 수'})
cs_seo['폐교년도'] = cs_seo['폐교년도'].astype('str')

# %%
#left join
cs_seoul = pd.merge(time_df, cs_seo, how='left')

# %%
#결측치들을 '0'으로 변환
cs_seoul = cs_seoul.fillna(0)

# %%
#시계열그래프 시각화_서울

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_seoul['폐교년도'], cs_seoul['폐교 수'], color = 'orange', label='Seoul')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Seoul Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper left', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_seoul.jpg')

# %%
#울산
ulsan = (cs_totals["시도교육청"] == '울산')
ulsan_if = cs_totals[ulsan]
cs_uls = ulsan_if.groupby(('폐교년도'),  as_index =False).count()
cs_uls = cs_uls.drop(['급별'], axis = 'columns')
cs_uls = cs_uls.rename(columns = {'시도교육청':'폐교 수'})
cs_uls['폐교년도'] = cs_uls['폐교년도'].astype('str')

# %%
#left join
cs_ulsan = pd.merge(time_df, cs_uls, how='left')

# %%
#결측치들을 '0'으로 변환
cs_ulsan = cs_ulsan.fillna(0)

# %%
#시계열그래프 시각화_울산

#그래프 크기
plt.figure(figsize = (30, 15))

#그래프 x 및 y행에 대한 데이터 지정
plt.plot(cs_ulsan['폐교년도'], cs_ulsan['폐교 수'], color = 'orange', label='Ulsan')

#x 눈금레이블 크기
plt.xticks(fontsize = 20)

#y 눈금레이블 크기
plt.yticks(fontsize = 20)

#x레이블 제목 크기 
plt.xlabel('year', fontsize = 30)

#y레이블 제목 크기
plt.ylabel('count', fontsize = 30)

#그림 제목 크기
plt.title('Ulsan Closed School', fontsize = 30)

#범례위치 및 크기 지정
plt.legend(loc = 'upper right', fontsize = 15)

plt.savefig('./graph_closeschool/Close_School_ulsan.jpg')

# %% [markdown]
# # 히트맵

# %%
from matplotlib import font_manager, rc
import platform 

# 그래프에서 한글 표기를 위한,
# 글자체 변경(윈도우, 맥os 각각의 경우에 대해서 처리)
if platform.system() == 'Windows': 
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)

# %%
cs_grby_re = cs_totals.groupby(['폐교년도', '시도교육청']).count()

# %%
#index 내용 column내용으로 빼기
cs_grby_re.reset_index(level= ['폐교년도', '시도교육청'], inplace= True)

# %%
df = cs_grby_re.pivot('시도교육청', '폐교년도', '급별')
df = df.fillna(0)

# %%
#히트맵 그래프 시각화
plt.figure(figsize = (20, 20))

sns.heatmap(df, annot= True)

plt.title('Each year with region', fontsize = 20)

plt.savefig('./heatmap.jpg')
